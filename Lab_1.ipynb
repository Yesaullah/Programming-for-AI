# %% [markdown]
# <a href="https://colab.research.google.com/github/Yesaullah/Programming-for-AI/blob/main/Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Task 1:**

# %%
weight = int(input("Enter your weight: "))
height = int(input("Enter your height: "))

BMI = weight/(height**2)
print("Your Body-Mass Index is: ", BMI)
# Out:
# Enter your weight: 60
# Enter your height: 170
# Your Body-Mass Index is:  0.0020761245674740486

# %% [markdown]
# # **Task 2:**

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

choice = input("Enter the function you want to perform: ")

if choice == "addition":
  print("Result: ", num1 - (-num2))
elif choice == "subtraction":
  print("Result: ", num1 - num2)
elif choice == "multiply":
  print("Result: ", num1*num2)
elif choice == "division":
  print("Result: ", num1/num2)
else:
  print("Invalid choice!\nChoose from: 'addition', 'subtraction', 'multiplication', 'division'")
# Out:
# Enter first number: 4
# Enter second number: 7
# Enter the function you want to perform: addition
# Result:  11

# %% [markdown]
# # **Task 3:**

# %%
n = int(input("Enter the number of integers: "))
count = 0
for i in range(0, n):
  num = int(input("Enter a number: "))
  if num%2 == 0:
    count += 1

print("Even numbers count: ", count)
# Out:
# Enter the number of integers: 6
# Enter a number: 1
# Enter a number: 2
# Enter a number: 3
# Enter a number: 4
# Enter a number: 5
# Enter a number: 6
# Even numbers count:  3

# %% [markdown]
# # **Task 4:**

# %%
n = int(input("Enter the number of integers: "))
sum = 0
for i in range(0, n):
  num = int(input("Enter a number: "))
  sum += num

print("Sum of all the elements: ", sum)
# Out:
# Enter the number of integers: 4
# Enter a number: 1
# Enter a number: 2
# Enter a number: 3
# Enter a number: 4
# Sum of all the elements:  10

# %% [markdown]
# # **Task 5:**

# %%
n = int(input("Enter the number of elements: "))
target = int(input("Enter the target integer: "))

nums = []

for i in range(0, n):
    num = int(input("Enter element {}: ".format(i+1)))
    nums.append(num)

print("Initial List: ", nums)

nums = [element for element in nums if element > target]
print("Final List: ", nums)
# Out:
# Enter the number of elements: 5
# Enter the target integer: 3
# Enter element 1: 6
# Enter element 2: 2
# Enter element 3: 7
# Enter element 4: 1
# Enter element 5: 0
# Initial List:  [6, 2, 7, 1, 0]
# Final List:  [6, 7]

# %% [markdown]
# # **Task 6:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
physics = int(input("Enter obtained marks in Physics: "))
chemistry = int(input("Enter obtained marks in Chemistry: "))
maths = int(input("Enter obtained marks in Maths: "))

marks = {
    "Physics": physics,
    "Chemistry": chemistry,
    "Maths": maths
}

sum = 0
highest = 0

for key, value in marks.items():
  sum += value
  if value > highest:
    subject = key
    highest = value

print("Average Marks: ", sum/3)
print(f"Highest marks are scored in {subject}")
# Out:
# Enter obtained marks in Physics: 40
# Enter obtained marks in Chemistry: 78
# Enter obtained marks in Maths: 82
# Average Marks:  66.66666666666667
# Highest marks are scored in Maths

# %% [markdown]
# # **Task 7:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
word = input("Enter a word: ")
letters_list = list(word)

final_list = []

for i in range(len(letters_list) - 1, -1, -1):
  final_list.append(letters_list[i])

print("Reversed string: ", ''.join(final_list))
# Out:
# Enter a word: Pakistan
# Reversed string:  natsikaP

# %% [markdown]
# # **Task 7:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for number in range(1, 51):
  if number % 3 == 0 and number % 5 == 0:
