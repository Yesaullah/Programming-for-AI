# %% [markdown]
# # **Task 01:**
# ![image.png](attachment:image.png)

# %%
a = ["He", "th", "i", "sal"]
b = ["llo", "is", "s", "man"]

zipped_list = [x+y for x, y in zip(a, b)]

print(zipped_list)
# Out:
# ['Hello', 'this', 'is', 'salman']

# %% [markdown]
# # **Task 02:**
# ![image.png](attachment:image.png)

# %%
list1 = ["Hello", "take"]
list2 = ["Dear", "Sir"]

result = [x + " " + y for x in list1 for y in list2]
print(result)
# Out:
# ['Hello Dear', 'Hello Sir', 'take Dear', 'take Sir']

# %% [markdown]
# # **Task 03:**
# ![image.png](attachment:image.png)

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def print_biodata(self):
        print("Student Biodata: ")
        print("Name: ", self.name)
        print("Age: ", self.age)


student1 = Student("Yesaullah", 19)
student1.print_biodata()
# Out:
# Student Biodata:
# Name:  Yesaullah
# Age:  19

# %% [markdown]
# # **Task 04:**
# ![image.png](attachment:image.png)

# %%
class Employee:
    def __init__(self):
        
    def getData(self):
        self.name = input("Enter Employee's Name: ")
        self.salary = int(input("Enter Monthly Salary: "))
        self.tax_percent = float(input("Enter Tax Percentage: "))
    def update_tax_percentage(self):
        self.tax_percent = 3
